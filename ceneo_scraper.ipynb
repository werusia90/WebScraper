# %%
pip install requests

# %%
pip install BeautifulSoup4

# %% [markdown]
# ## Import bibliotek

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Pobranie z serwisu Ceneo.pl opinii o wybranym produkcie

# %%
url = "https://www.ceneo.pl/47293506#tab=reviews"
response= requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
headers = {
    "Cookie": "__RequestVerificationToken=vFJJ405BdPUHMQOnLgIbd1ZR6EWIfOKkn5-aVT8Zmaux199F5prT1Y-IRbiNLV_s1wYFf0MFqSS9uw6jkdz26BFy52bDKZKqZbtF1vOhnXI1; userCeneo=ID=f88f9550-1af8-49ed-87ff-429eff29f1b2; ai_user=U02E|2026-03-12T13:21:21.840Z; _fbp=fb.1.1773321690029.539233279292178956; __utmf=51dd22322161aea07ad1c87268b0b0cc_k2wCRI6tAVSgxOOwMsWh%2Bvo35Yf981ST; appType=%7B%22Value%22%3A1%7D; cProdCompare_v2=; browserBlStatus=0; cto_bundle=Eo7TGF8zc25VUEs1S09LUG9OUGllJTJGZHplVnZ3RmtueU00TFkxcExuUDBYWElWcmtjT3JXdEVvek15anlMOTBvREJKJTJGJTJCQlQ3VEJyTyUyRjBSb0NVQ3N3UGtvZEFpam8yVUo4eXFnZ2lMdW9haGdYUUZ2UHRKUE5JNFRVWFY1REtteE1HQ2pu; ga4_ga=GA1.2.5a721040-1e16-11f1-aa8c-4bc8355c62d3; _gcl_au=1.1.975693911.1773321700; FPID=FPID2.2.BxkkHGvbZykjHMzHFrmVMnKyonii%2FuttDj3VXw70i1o%3D; FPLC=u0u%2FEJ2VBOkAC5QQLPBaD2JITVGoqXFyIKCtr6KwcEqSkGOkcTIF910yGsFjXa2AYsPXomRbSQiQ5gTggOLjdBI0IQwYPOdASlbygQJzTSoA0ZM%3D; consentcookie=...; __gads=ID=37b6c26a126a21c7:T=1773321779:RT=1773321779:S=ALNI_MbKpbB_BSGBLTzMba6WtKz5wKgz3A; __gpi=UID=0000134ceeb6ee04:T=1773321779:RT=1773321779:S=ALNI_MbFI0FVpyz6OPrVIOqyGr2G1RfttQ; _tt_enable_cookie=1; _ttp=01KKH3DYJJXGJK5Q8RXVJ5A14C_.tt.1; rc=igdamb4ThORBsYaBd8YIPZoTFF+iZGR+1RLplVHKu6dw58lXb5M+wX9WfBoRHToajcO9VZaXTiPPyQVICwMC2WKgI2eFTIH6rq8e3tcPTT9/VnwaER06Go3DvVWWl04jz8kFSAsDAtlioCNnhUyB+tEo2dcvD3e8/+sN1fF7+A4bAEXzDghU/1LV6Czu0sMkhMazhpyH5RRJTHiW+LAawQ==; __rtbh.lid=%7B%22eventType%22%3A%22lid%22%2C%22id%22%3A%22grR6z8bDJB1lihgbIPct%22%2C%22expiryDate%22%3A%222027-03-12T13%3A26%3A32.997Z%22%7D; __rtbh.aid=%7B%22eventType%22%3A%22aid%22%2C%22id%22%3A%225a721040-1e16-11f1-aa8c-4bc8355c62d3%22%2C%22expiryDate%22%3A%222027-03-12T13%3A26%3A33.001Z%22%7D; __rtbh.uid=%7B%22eventType%22%3A%22uid%22%2C%22id%22%3A%22unknown%22%2C%22expiryDate%22%3A%222027-03-12T13%3A26%3A33.007Z%22%7D; __eoi=ID=1a20ea732a87eb11:T=1773321691:RT=1773321993:S=AA-AfjY6d1xS5egtPGiLCvYcOqgD; ttcsid_CNK74OBC77U1PP7E4UR0=1773321779796::tr0N4WgsFr3g3UpqIA5q.1.1773321993260.1; ttcsid=1773321779796::y5NJs5Wx_BTRyd2qkVRo.1.1773321993260.0; ga4_ga_K2N2M0CBQ6=GS2.2.s1773321688$o1$g1$t1773321994$j59$l0$h1358142110; ai_session=0sqfp|1773321690201|1773321994024.6"
    "user_"

}

# %%
page_dom = BeautifulSoup(response.text,"html.parser")
print(page_dom)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="2" http-equiv="refresh">
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Ceneo - porównanie cen, sklepy internetowe - kup najtaniej</title>
# <style>
# html {
# --max-width: 1464px;
# --primary-color: #ff6400;
# --secondary-color: #0071c5;
# --background-color: #f2f5f7;
# --card-color: #fff;
# }
# body {
# background-color: var(--background-color);
# font-family: "Segoe UI", Tahoma, Geneva, Verdana, sans-serif;
# }
# header {
# max-width: var(--max-width);
# margin: 0 auto;
# padding: .625rem;
# }
# section {
# max-width: var(--max-width);
# margin: 0 auto;
# padding: .625rem;
# }
# .button-primary {
# color: #fff;
# background-color: #ff6400;
# display: inline-block;
# min-width: 140px;
# text-align: center;
# box-sizing: border-box;
# line-height: 1;
# border: none;
# outline: 0;
# padding: 0.5rem .625rem;
# ...

# %%
opinions = page_dom.find_all("div",class_ = "js_product-reviews")
